# %%
import pandas as pd 
import matplotlib.pyplot as plt  
import re
import numpy as np
import json

# %%
olddata_path = 'old data - FOW | Driving Game_October 12, 2023_23.csv'
newdata_path = 'new data - FOW | Driving Game_November 14, 2023_18.csv'
old_df = pd.read_csv(olddata_path)
new_df = pd.read_csv(newdata_path)

# %%
old_df = old_df[['GameResult']]
single = old_df.at[2, 'GameResult']
single = json.loads(single)
single
# Out:
# [{'time': 0, 'event': 'brandon started a game with 1200 timeLimit'},
#  {'time': 0,
#   'event': 'Entered home screen, displayed jobs: ["i:(0,2754) UberEats - SF: 39 waitTime, 51 timeLimit","i:(1,4217) Uber - SF: 1 waitTime, 20 timeLimit","i:(2,4595) UberEats - Berkeley: 56 waitTime, 52 timeLimit","i:(3,2174) Uber - Berkeley: 14 waitTime, 29 timeLimit"]'},
#  {'time': 0.999, 'event': 'i:(1,1777) Job Uber - SF now avaliable'},
#  {'time': 14.002, 'event': 'i:(3,2333) Job Uber - Berkeley now avaliable'},
#  {'time': 20.256,
#   'event': 'Task Uber - Berkeley was started with: 14 steps, 29 timeLimit, 32 hardLimit'},
#  {'time': 24.122, 'event': '(14) Correct Guess: red'},
#  {'time': 25.578, 'event': '(13) Correct Guess: yellow'},
#  {'time': 27.002, 'event': '(12) Correct Guess: yellow'},
#  {'time': 28.242, 'event': '(11) Correct Guess: red'},
#  {'time': 30.744, 'event': '(10) Correct Guess: yellow'},
#  {'time': 32.177, 'event': '(9) Correct Guess: green'},
#  {'time': 33.315, 'event': '(8) Correct Guess: red'},
#  {'time': 34.87, 'event': '(7) Correct Guess: yellow'},
#  {'time': 36.294, 'event': '(6) Correct Guess: yellow'},
#  {'time': 37.604, 'event': '(5) Correct Guess: green'},
#  {'time': 48.671, 'event': '(4) Correct Guess: red'},
#  {'time': 49.982, 'event': '(3) Correct Guess: yellow'},
#  {'time': 51.009, 'event': '(2) Correct Guess: red'},
#  {'time': 52.26,
#   'event': 'Ended with: 0 mistakes, 0 earned, 32 in game time passed'},
#  {'time': 54.454, 'event': 'Changed rating: 1'},
#  {'time': 57.581, 'event': 'Changed rating: 0'},
#  {'time': 58.179, 'event': 'Changed rating: -1'},
#  {'time': 58.92, 'event': 'Changed rating: 0'},
#  {'time': 60.03, 'event': 'Changed rating: 1'},
#  {'time': 60.768, 'event': 'Changed rating: 0'},
#  {'time': 61.311, 'event': 'Changed rating: -1'},
#  {'time': 61.695, 'event': 'Changed rating: 0'},
#  {'time': 66.551, 'event': 'Rated themselves: 0'},
#  {'time': 66.551,
#   'event': 'Entered home screen, displayed jobs: ["i:(0,3181) UberEats - SF: 4 waitTime, 27 timeLimit","i:(1,466) Uber - SF: 16 waitTime, 14 timeLimit","i:(2,1157) UberEats - Berkeley: 35 waitTime, 24 timeLimit","i:(3,1440) Uber - Berkeley: 4 waitTime, 25 timeLimit"]'},
#  {'time': 70.545, 'event': 'i:(3,4492) Job Uber - Berkeley now avaliable'},
#  {'time': 70.545, 'event': 'i:(0,4107) Job UberEats - SF now avaliable'},
#  {'time': 82.552, 'event': 'i:(1,3380) Job Uber - SF now avaliable'},
#  {'time': 84.279,
#   'event': 'Task Uber - Berkeley was started with: 12 steps, 25 timeLimit, 50 hardLimit'},
#  {'time': 86.533, 'event': '(12) Correct Guess: yellow'},
#  {'time': 87.648, 'event': '(11) Correct Guess: red'},
#  {'time': 88.959, 'event': '(10) Correct Guess: yellow'},
#  {'time': 90.189, 'event': '(9) Correct Guess: green'},
#  {'time': 91.542, 'event': '(8) Correct Guess: yellow'},
#  {'time': 92.468, 'event': '(7) Correct Guess: red'},
#  {'time': 93.378, 'event': '(6) Correct Guess: red'},
#  {'time': 94.135, 'event': '(5) Correct Guess: red'},
#  {'time': 95.569, 'event': '(4) Correct Guess: yellow'},
#  {'time': 96.386, 'event': '(3) Correct Guess: red'},
#  {'time': 98.043, 'event': '(2) Correct Guess: green'},
#  {'time': 99.283, 'event': '(1) Correct Guess: yellow'},
#  {'time': 99.283,
#   'event': 'Ended with: 0 mistakes, 25 earned, 15 in game time passed'},
#  {'time': 101.059, 'event': 'Changed rating: 1'},
#  {'time': 101.724, 'event': 'Rated themselves: 1'},
#  {'time': 101.724, 'event': 'i:(3,1386) Job Uber - Berkeley now avaliable'},
#  {'time': 101.724, 'event': 'i:(1,4585) Job Uber - SF now avaliable'},
#  {'time': 101.724,
#   'event': 'Entered home screen, displayed jobs: ["i:(0,2061) UberEats - SF: 7 waitTime, 17 timeLimit","i:(1,4585) Uber - SF: 0 waitTime, 16 timeLimit","i:(2,3699) UberEats - Berkeley: 32 waitTime, 35 timeLimit","i:(3,1386) Uber - Berkeley: 0 waitTime, 22 timeLimit"]'},
#  {'time': 101.724, 'event': 'i:(3,1675) Job Uber - Berkeley now avaliable'},
#  {'time': 101.724, 'event': 'i:(1,1139) Job Uber - SF now avaliable'},
#  {'time': 104.338,
#   'event': 'Task Uber - Berkeley was started with: 11 steps, 22 timeLimit, 38 hardLimit'},
#  {'time': 107.155, 'event': '(11) Correct Guess: red'},
#  {'time': 108.922, 'event': '(10) Correct Guess: green'},
#  {'time': 110.153, 'event': '(9) Correct Guess: yellow'},
#  {'time': 111.962, 'event': '(8) Correct Guess: green'},
#  {'time': 113.009, 'event': '(7) Correct Guess: red'},
#  {'time': 114.602, 'event': '(6) Correct Guess: green'},
#  {'time': 115.522, 'event': '(5) Correct Guess: red'},
#  {'time': 116.601, 'event': '(4) Correct Guess: green'},
#  {'time': 118.042, 'event': '(3) Correct Guess: green'},
#  {'time': 119.071, 'event': '(2) Correct Guess: green'},
#  {'time': 120.144, 'event': '(1) Correct Guess: green'},
#  {'time': 120.144,
#   'event': 'Ended with: 0 mistakes, 22 earned, 15 in game time passed'},
#  {'time': 122.234, 'event': 'Changed rating: 1'},
#  {'time': 123.235, 'event': 'Rated themselves: 1'},
#  {'time': 123.235,
#   'event': 'Entered home screen, displayed jobs: ["i:(0,4657) UberEats - SF: 5 waitTime, 28 timeLimit","i:(1,1856) Uber - SF: 2 waitTime, 18 timeLimit","i:(2,2888) UberEats - Berkeley: 26 waitTime, 43 timeLimit","i:(3,250) Uber - Berkeley: 3 waitTime, 15 timeLimit"]'},
#  {'time': 125.233, 'event': 'i:(1,4454) Job Uber - SF now avaliable'},
#  {'time': 126.235, 'event': 'i:(3,3542) Job Uber - Berkeley now avaliable'},
#  {'time': 128.236, 'event': 'i:(0,2365) Job UberEats - SF now avaliable'},
#  {'time': 134.562,
#   'event': 'Task Uber - SF was started with: 9 steps, 18 timeLimit, 44 hardLimit'},
#  {'time': 138.497, 'event': '(9) Correct Guess: yellow'},
#  {'time': 139.659, 'event': '(8) Correct Guess: red'},
#  {'time': 140.851, 'event': '(7) Correct Guess: red'},
#  {'time': 142.324, 'event': '(6) Correct Guess: green'},
#  {'time': 143.452, 'event': '(5) Correct Guess: red'},
#  {'time': 144.442, 'event': '(4) Correct Guess: red'},
#  {'time': 145.239, 'event': '(3) Correct Guess: red'},
#  {'time': 146.652, 'event': '(2) Correct Guess: yellow'},
#  {'time': 150.044, 'event': '(1) Correct Guess: yellow'},
#  {'time': 150.044,
#   'event': 'Ended with: 0 mistakes, 18 earned, 15 in game time passed'},
#  {'time': 339.502, 'event': 'Changed rating: 1'},
#  {'time': 340.251, 'event': 'Rated themselves: 1'},
#  {'time': 340.251,
#   'event': 'Entered home screen, displayed jobs: ["i:(0,2147) UberEats - SF: 3 waitTime, 38 timeLimit","i:(1,1555) Uber - SF: 7 waitTime, 21 timeLimit","i:(2,348) UberEats - Berkeley: 17 waitTime, 41 timeLimit","i:(3,98) Uber - Berkeley: 5 waitTime, 25 timeLimit"]'},
#  {'time': 343.25, 'event': 'i:(0,1148) Job UberEats - SF now avaliable'},
#  {'time': 345.256, 'event': 'i:(3,571) Job Uber - Berkeley now avaliable'},
#  {'time': 347.255, 'event': 'i:(1,1572) Job Uber - SF now avaliable'},
#  {'time': 349.555,
#   'event': 'Task UberEats - SF was started with: 12 steps, 38 timeLimit, 70 hardLimit'},
#  {'time': 352.458, 'event': '(12) Correct Guess: pineapple'},
#  {'time': 354.142, 'event': '(11) Correct Guess: coconut'},
#  {'time': 355.698, 'event': '(10) Correct Guess: banana'},
#  {'time': 357.25, 'event': '(9) Correct Guess: coconut'},
#  {'time': 358.793, 'event': '(8) Correct Guess: banana'},
#  {'time': 361.891, 'event': '(7) Incorrect Guess: coconut, mistyped cocnut'},
#  {'time': 363.979, 'event': '(7) Correct Guess: coconut'},
#  {'time': 365.331, 'event': '(6) Correct Guess: apple'},
#  {'time': 367.387, 'event': '(5) Correct Guess: banana'},
#  {'time': 369.045, 'event': '(4) Correct Guess: apple'},
#  {'time': 370.235, 'event': '(3) Incorrect Guess: banana, mistyped banaa'},
#  {'time': 371.223, 'event': '(3) Correct Guess: banana'},
#  {'time': 372.908, 'event': '(2) Correct Guess: pineapple'},
#  {'time': 374.604, 'event': '(1) Correct Guess: apple'},
#  {'time': 374.604,
#   'event': 'Ended with: 2 mistakes, 38 earned, 23 in game time passed'},
#  {'time': 376.424, 'event': 'Rated themselves: 0'},
#  {'time': 376.424,
#   'event': 'Entered home screen, displayed jobs: ["i:(0,2100) UberEats - SF: 3 waitTime, 47 timeLimit","i:(1,477) Uber - SF: 5 waitTime, 23 timeLimit","i:(2,3795) UberEats - Berkeley: 27 waitTime, 46 timeLimit","i:(3,4379) Uber - Berkeley: 15 waitTime, 13 timeLimit"]'},
#  {'time': 379.423, 'event': 'i:(0,2584) Job UberEats - SF now avaliable'},
#  {'time': 381.128,
#   'event': 'Task UberEats - SF was started with: 15 steps, 47 timeLimit, 106 hardLimit'},
#  {'time': 384.277, 'event': '(15) Correct Guess: banana'},
#  {'time': 385.651, 'event': '(14) Correct Guess: coconut'},
#  {'time': 386.792, 'event': '(13) Correct Guess: banana'},
#  {'time': 388.195, 'event': '(12) Correct Guess: banana'},
#  {'time': 389.468, 'event': '(11) Correct Guess: apple'},
#  {'time': 390.639, 'event': '(10) Correct Guess: apple'},
#  {'time': 392.052, 'event': '(9) Correct Guess: banana'},
#  {'time': 393.868, 'event': '(8) Correct Guess: apple'},
#  {'time': 395.543, 'event': '(7) Correct Guess: pineapple'},
#  {'time': 396.824, 'event': '(6) Correct Guess: coconut'},
#  {'time': 398.985, 'event': '(5) Correct Guess: pineapple'},
#  {'time': 400.418, 'event': '(4) Correct Guess: apple'},
#  {'time': 402.223, 'event': '(3) Correct Guess: pineapple'},
#  {'time': 403.687, 'event': '(2) Correct Guess: apple'},
#  {'time': 405.486, 'event': '(1) Correct Guess: apple'},
#  {'time': 405.486,
#   'event': 'Ended with: 0 mistakes, 47 earned, 24 in game time passed'},
#  {'time': 407.754, 'event': 'Changed rating: 1'},
#  {'time': 408.117, 'event': 'Changed rating: 0'},
#  {'time': 411.175, 'event': 'Rated themselves: 0'},
#  {'time': 411.175,
#   'event': 'Entered home screen, displayed jobs: ["i:(0,1186) UberEats - SF: 18 waitTime, 19 timeLimit","i:(1,3617) Uber - SF: 1 waitTime, 23 timeLimit","i:(2,4468) UberEats - Berkeley: 4 waitTime, 34 timeLimit","i:(3,4214) Uber - Berkeley: 10 waitTime, 22 timeLimit"]'},
#  {'time': 412.175, 'event': 'i:(1,2785) Job Uber - SF now avaliable'},
#  {'time': 415.171,
#   'event': 'i:(2,4837) Job UberEats - Berkeley now avaliable'},
#  {'time': 421.178, 'event': 'i:(3,4295) Job Uber - Berkeley now avaliable'},
#  {'time': 429.175, 'event': 'i:(0,1414) Job UberEats - SF now avaliable'},
#  {'time': 1200.506, 'event': 'Finished Game'}]
